# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv("C:\Pallav\Python-Data-Science-and-Machine-Learning-Bootcamp\Python-Data-Science-and-Machine-Learning-Bootcamp\Python-for-Data-Visualization\Pandas Built-in Data Viz\df1",
                 index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv("C:\Pallav\Python-Data-Science-and-Machine-Learning-Bootcamp\Python-Data-Science-and-Machine-Learning-Bootcamp\Python-for-Data-Visualization\Pandas Built-in Data Viz\df2",
                 )

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist() # internally it is calling matplotlib library. You can use any matplotlib related parameters

# %%
df1['A'].hist(bins = 30)

# %%
df1['A'].plot(kind = 'hist', bins = 30)

# %%
df1['A'].plot.hist(bins = 30)

# %%
df2.plot.area(alpha = 0.4, figsize = (12,4))  # this is area plot

# %%
df2.plot.bar(figsize = (12,5))

# %%
df2.plot.bar(figsize = (12,5), stacked = True)

# %%
df1['A'].plot.line(x = df1.index , y = 'B' , figsize = (10,4), lw =1) # everything about matplotlib is applicable

# %%
df1.plot.scatter(x = 'A' , y='B', figsize = (10,4))

# %%
df1.plot.scatter(x = 'A' , y='B', c = 'C', figsize = (10,4), cmap = 'rainbow')

# %%
df1.plot.scatter(x = 'A' , y='B', s = df1['C']*10)
# Out:
# C:\Python3\Anaconda3\lib\site-packages\matplotlib\collections.py:865: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a' ,'b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.557482  0.865545
# 1  0.933123  1.344582
# 2 -0.567869  0.757140
# 3  0.867400 -0.339834
# 4 -1.637892 -0.121454

# %%
df.plot.hexbin(x = 'a' , y= 'b',gridsize=40, figsize = (12,8), cmap = 'coolwarm' )

# %%
df2['a'].plot.kde()  # Kernal density estimate plot

# %%
df2.plot.density()

# %% [markdown]
# # Pandas Data Visualization Exercise

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df3 = pd.read_csv('C:\Pallav\Python-Data-Science-and-Machine-Learning-Bootcamp\Python-Data-Science-and-Machine-Learning-Bootcamp\Python-for-Data-Visualization\Pandas Built-in Data Viz\df3')
# %matplotlib inline

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.plot.scatter(x= 'a' , y= 'b' , color = 'red' , figsize = (12,3), s =50)

# %%
#Create a histogram of the 'a' column.
plt.style.use('ggplot')
df3['a'].plot.hist( bins = 30, alpha = 0.4)

# %%
df3.boxplot(column=['a','b'] )

# %%
df3['d'].plot.kde(lw = 3, ls='--')

# %%
df3.head(30).plot.area( alpha = 0.5)

# %%
df3.ix[0:30].plot.area( alpha = 0.5)

# %%
f= plt.figure()
df3.ix[0:30].plot.area( alpha = 0.5)
plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.7))
plt.show()
